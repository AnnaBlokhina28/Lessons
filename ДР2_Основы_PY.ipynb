# %% [markdown]
# <font color="#8B0000"><h1><b>Урок 2. Анализ датасета с помощью Pandas</b></h1></font>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <font color="#C71585"><h2><b>Задача 1</b></h2></font>
#
# Скачать данные по ссылке https://www.kaggle.com/datasets/shivachandel/kc-house-data
# Файл прикрепил к материалам kc_house_data.csv
# Считать данные с помощью pandas
# Вывести на экран первые 5 строк
# Посмотреть на описание признаков и на их содержание
#
# <b>Выводы</b> В данных приведена характеристика домов.
# <br>id-ID в списке</br>
# <br>date-дата выставления на продажу</br>
# <br>price-цена дома</br>
# <br>bedrooms-количество спален</br>
# <br>bathrooms-количество ванн</br>
# <br>sqft_living - жилая площадь</br>
# <br>sqft_lot - площадь дома</br>
# <br>floors-количество этажей</br><br>waterfront-близость к набережной</br>
# <br>view - вид из окна</br>
# <br>condition - состояние дома</br>
# <br>grade - оценка</br>
# <br>sqft_above - площадь чердака</br>
# <br>sqft_basement - площадь подвала</br>
# <br>yr_built - год постройки</br>
# <br>yr_renovated - год ремонта</br>
# <br>zipcode - индекс</br>
# <br>lat-координата широты</br>
# <br>long-координата долготы</br>
# <br>sqft_living15 -  Площадь гостиной в 2015 году (подразумевается - некоторые ремонтные работы). Это могло повлиять или не повлиять на площадь участка. </br>
# <br>sqft_lot15 - площадь лота в 2015 году (подразумевается - некоторые ремонтные работы)</br>

# %%
df = pd.read_csv('./kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %% [markdown]
# <font color="#C71585"><h2><b>Задача 2</b></h2></font>
#
# Проведите первичный анализ данных
# Изучите типы данных
# Найдите количество пропущенных ячеек в данных
# Посчитайте основные статистики по всем признакам и поизучайте их
# Пишите выводы
#
# <b>Выводы</b>: Пропущенных ячеек в данных нет. Данные имеют одно строковое(date), целочисленные и вещественные значения.
# <br><i>price</i>: Среднее значение цены за дом - 540088 долларов. Отклонение цены от средней 367127.2 долларов. Был продан дом за минимальную стоимость 75000 долларов. Максимальная цена за дом -7700000 долларов. Если отсортировать все цены от меньшей к большей то 25-ти процентный квантиль равен 321950 долларов, 50% -450000 долларов,75%-645000 долларов</br>
# <br><i>sqft_living</i> Средняя жилая площадь домов 2080 кв. м, максимальная жилая площадь дома 13540 кв.м.. Минимальная жилая площадь дома 290 кв.м. </br>
# <br><i>yr_built</i> В среденем дома продаются 1970-х годов и по среденй(1971) и по квантилю 50% - (1975). Самые старые дома 1900 года постройки. Самый новый 2015 года.</br>
# <br><i>condition</i> Состояние домой в среденем удовлетворительное на оценку 3 из 5. Оценку 1 и 2 имеют меньше 25% домов.</br>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# <font color="#C71585"><h2><b>Задача 3</b></h2></font>
#
# Ответьте на несколько вопросов
# ### 3.1 В каком диапазоне изменяются стоимости недвижимости?
#
# Ответ: Диапазон цены: 75000-7700000 долларов

# %%
df['price'].min()
# Out:
# 75000.0

# %%
df['price'].max()
# Out:
# 7700000.0

# %% [markdown]
# ### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?
#
# Ответ: Доля средней жилой площади от всей площади по всем домам составляет 13.8%

# %%
df["sqft_living"].mean()*100/df["sqft_lot"].mean()
# Out:
# 13.76781757959227

# %% [markdown]
# ### 3.3 Как много домов с разными этажами в данных?

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# ### 3.4 Насколько хорошие состояния у домов в данных?
#
# Вывод: Состояние домой в среденем удовлетворительное на оценку 3 из 5. Оценку 1 и 2 имеют 202 дома, что составляет всего 1 процент. 65% домов имеют оценку 3. 34% - имеют оценку состояния 4 и 5 это 7380 домов.

# %%
df['condition'].value_counts(normalize=True)
# Out:
# 3    0.649193
# 4    0.262759
# 5    0.078703
# 2    0.007958
# 1    0.001388
# Name: condition, dtype: float64

# %%
df[df['condition'].isin([4, 5])]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 11     9212900260  20140527T000000  468000.0         2       1.00
# 12      114101516  20140528T000000  310000.0         3       1.00
# 13     6054650070  20141007T000000  400000.0         3       1.75
# 17     6865200140  20140529T000000  485000.0         4       1.00
# ...           ...              ...       ...       ...        ...
# 21079  3449000010  20150312T000000  294570.0         3       1.00
# 21212  7234600098  20140905T000000  552100.0         3       3.00
# 21303   522059130  20150429T000000  465000.0         3       1.00
# 21332  9266700190  20150511T000000  245000.0         1       1.00
# 21583  2025049203  20140610T000000  399950.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3             1960      5000     1.0           0     0  ...      7
# ...

# %% [markdown]
# ### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?
# Ответ: Самые старые дома 1900 года постройки их 87 штук. Самые новые дома построины в 2015 году.

# %%
df1 = df[df['yr_built'] == 1900]
df1
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 14     1175000570  20150312T000000  530000.0         5       2.00
# 115    3626039325  20141121T000000  740500.0         3       3.50
# 498    9274202270  20140818T000000  625000.0         2       1.50
# 537    5694500105  20141204T000000  595000.0         2       2.00
# 703    7011200260  20141219T000000  485000.0         4       2.00
# ...           ...              ...       ...       ...        ...
# 19063  1702901340  20140613T000000  718500.0         3       2.00
# 19137  3388110230  20140729T000000  179000.0         4       1.75
# 19319  4083302225  20141014T000000  850000.0         4       3.00
# 19385  2420069042  20150424T000000  240000.0         3       2.00
# 19598  7518507685  20150223T000000  400000.0         3       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14            1810      4850     1.5           0     0  ...      7
# ...

# %% [markdown]
# <font color="#C71585"><h2><b>Задача 4</b></h2></font>
#
# Ответьте на несколько вопросов
#
# ### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?
#
# Ответ: 401373 долларов

# %%
df1 = df[df['bedrooms'] == 2]
df1[['price']].mean()
# Out:
# price    401372.681884
# dtype: float64

# %% [markdown]
# ### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?
#
# Ответ: 20455 кв.м.

# %%
df2 = df[df['price'] >= 600000]
df2[['sqft_lot']].mean()
# Out:
# sqft_lot    20454.783538
# dtype: float64

# %% [markdown]
# ### 4.3 Как много домов коснулся ремонт?
#
# Ответ:Ремонт был в 914-ти домах

# %%
df[~(df['yr_renovated'] == 0)].shape
# Out:
# (914, 21)

# %% [markdown]
# ### 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?
#
# Ответ: Стоимость отличается на 1488885 долларов

# %%
df3 = df[df['grade'] > 10]
df4 = df[df['grade'] < 4]
df3[['price']].mean() - df4[['price']].mean()
# Out:
# price    1.488885e+06
# dtype: float64

# %% [markdown]
# <font color="#C71585"><h2><b>Задача 5</b></h2></font>
#
# Ответьте на несколько вопросов
#
# ### 5.1 Выберите дом клиенту
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?
#
# Ответ: У клиента 84 варианта

# %%
df5=df[(df['waterfront'] ==1) & (df['bedrooms'] >= 3) & (df['sqft_basement'] != 0)]
df5.shape
# Out:
# (84, 21)

# %% [markdown]
# ### 5.2 Выберите дом клиенту
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?
#
# Ответ: Дома ценовом диапазоне 1295000 - 3000000 долларов

# %%
pd.set_option('display.max_columns', None) 
df6=df[((df['waterfront'] ==1)|(df['view'] ==4))&(df['condition'] == 5)&(df['yr_built'] >= 1980)]
df6['price'].describe()
# Out:
# count    5.000000e+00
# mean     1.789320e+06
# std      6.958016e+05
# min      1.295000e+06
# 25%      1.411600e+06
# 50%      1.505000e+06
# 75%      1.735000e+06
# max      3.000000e+06
# Name: price, dtype: float64

# %% [markdown]
# ### 5.3 Выберите дом клиенту
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?
#
# Ответ: Оценка сотояния домов в среденем 2.8 из 5

# %%
df7 = df[(df['sqft_basement'] == 0)&(df['floors']==2)&(df['price']<150000)]
df7[['condition']].mean()
# Out:
# condition    2.833333
# dtype: float64
